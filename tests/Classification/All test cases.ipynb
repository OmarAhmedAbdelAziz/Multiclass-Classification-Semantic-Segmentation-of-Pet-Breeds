# %%
# !pytest test_data_loader.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1 -- C:\Users\omara\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: d:\Courses and Projects\All Projects\My Main Projects\Multiclass Classification&Semantic Segmentation of Pet Breeds\tests
# plugins: anyio-3.7.0, dash-2.14.0, typeguard-2.13.3
# collecting ... collected 6 items
#
# test_data_loader.py::test_read_annotation_file PASSED                    [ 16%]
# test_data_loader.py::test_extracting_breed_name[Abyssinian_1-Abyssinian] PASSED [ 33%]
# test_data_loader.py::test_extracting_breed_name[bengal_5-bengal] PASSED  [ 50%]
# test_data_loader.py::test_extracting_breed_name[RandomBreed_100-RandomBreed] PASSED [ 66%]
# test_data_loader.py::test_extracting_breed_name[NoNumber-NoNumber] PASSED [ 83%]
# test_data_loader.py::test_load_pet_dataset PASSED                        [100%]
#
# ...

# %%
# !pytest test_preprocess.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1 -- C:\Users\omara\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: d:\Courses and Projects\All Projects\My Main Projects\Multiclass Classification&Semantic Segmentation of Pet Breeds\tests
# plugins: anyio-3.7.0, dash-2.14.0, typeguard-2.13.3
# collecting ... collected 3 items
#
# test_preprocess.py::test_preprocessing_images PASSED                     [ 33%]
# test_preprocess.py::test_split_dataset PASSED                            [ 66%]
# test_preprocess.py::test_create_data_generator PASSED                    [100%]
#
# ============================== warnings summary ===============================
# C:\Users\omara\anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
# ...

# %%
# !pytest test_predict.py -v
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.9.7, pytest-6.2.4, py-1.10.0, pluggy-0.13.1 -- C:\Users\omara\anaconda3\python.exe
# cachedir: .pytest_cache
# rootdir: d:\Courses and Projects\All Projects\My Main Projects\Multiclass Classification&Semantic Segmentation of Pet Breeds\tests
# plugins: anyio-3.7.0, dash-2.14.0, typeguard-2.13.3
# collecting ... collected 4 items
#
# test_predict.py::test_load_and_preprocess_image_valid PASSED             [ 25%]
# test_predict.py::test_load_and_preprocess_image_invalid PASSED           [ 50%]
# test_predict.py::test_predict_breed PASSED                               [ 75%]
# test_predict.py::test_display_prediction PASSED                          [100%]
#
# ============================== warnings summary ===============================
# C:\Users\omara\anaconda3\lib\site-packages\pyreadline\py3k_compat.py:8
# ...
